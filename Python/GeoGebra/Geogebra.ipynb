# %%
import pandas as pd
import matplotlib.pyplot as plt
import math

# %%
# %matplotlib inline

def calc_func(l_rng=-5, h_rng=5, y_rng=100, func=None):
#     func_dict = {}
    x_vals = []
    y_vals = []
    is_defined = []
    divider = 100
    for x in range(l_rng*divider, (divider*h_rng)+1):    
        x = x/divider
        
        try:
            # ------------------------------------
            # Insert Expression Here:
            func_x = func(x)
            # ------------------------------------
            
            x_vals.append(x)
            y_vals.append(func_x)
            if abs(func_x) > int(y_rng):
                is_defined.append(999)
            else:
                is_defined.append(1)
            
        except:
            x_vals.append(x)
            y_vals.append(0)
            is_defined.append(0)
    return pd.DataFrame({'X':x_vals, 'Y':y_vals, 'isDefined':is_defined})

# %%
def show_function(df):

    df_def = df[df['isDefined'] == 1]
    
#     arr = np.random.normal(1, 1, size=100)
    fig, ax = plt.subplots()
    
    ax.plot(df_def['X'], df_def['Y'], marker='o', lw=0)

    df_undef = df[df['isDefined'] == 0]
    ax.plot(df_undef['X'], df_undef['Y'], marker='o', color='r', lw=0)


    axes_limit = 2

    if max(df_def['X'])+axes_limit >= 0 and min(df_def['X'])-axes_limit <= 0:
        ax.axvline(linewidth=1, color='k')
    if max(df_def['Y'])+axes_limit >= 0 and min(df_def['Y'])-axes_limit <= 0:    
        ax.axhline(linewidth=1, color='k')
#     plt.show()
    
    return fig

# %%
def func_exp(x):
#     return (6*x**2 + 8*x) / (math.sqrt(2*x**3 + 4*x**2))
#     return x ** 2
    return x**2 - 1

def sin_func(x):
#     return (6*x**2 + 8*x) / (math.sqrt(2*x**3 + 4*x**2))
    rad_to_degree = (x/360)*(2*math.pi)
    return math.sin(rad_to_degree)

def tan_func(x):
#     return (6*x**2 + 8*x) / (math.sqrt(2*x**3 + 4*x**2))
    rad_to_degree = (x/360)*(2*math.pi)
    return math.tan(rad_to_degree)

# %%
edges = 30
highest_y = 20
df = calc_func(-edges, edges, highest_y, func_exp)

show_function(df)

# %%
df[(df['X'] > 3) & (df['X'] < 3.2)]
# Out:
#          X       Y  isDefined  isSwitch
# 3301  3.01  8.0601          1         0
# 3302  3.02  8.1204          1         0
# 3303  3.03  8.1809          1         0
# 3304  3.04  8.2416          1         0
# 3305  3.05  8.3025          1         0
# 3306  3.06  8.3636          1         0
# 3307  3.07  8.4249          1         0
# 3308  3.08  8.4864          1         0
# 3309  3.09  8.5481          1         0
# 3310  3.10  8.6100          1         0
# 3311  3.11  8.6721          1         0
# 3312  3.12  8.7344          1         0
# 3313  3.13  8.7969          1         0
# 3314  3.14  8.8596          1         0
# 3315  3.15  8.9225          1         0
# 3316  3.16  8.9856          1         0
# 3317  3.17  9.0489          1         0
# 3318  3.18  9.1124          1         0
# 3319  3.19  9.1761          1         0

# %%
df['isSwitch'] = df.apply(lambda x:  1 if x.name > 0 and df.loc[x.name - 1, 'Y'] / df.loc[x.name, 'Y'] < 0 else 0  , axis=1)
df
# Out:
# <ipython-input-51-639682bb2010>:1: RuntimeWarning: divide by zero encountered in double_scalars
#   df['isSwitch'] = df.apply(lambda x:  1 if x.name > 0 and df.loc[x.name - 1, 'Y'] / df.loc[x.name, 'Y'] < 0 else 0  , axis=1)
#           X         Y  isDefined  isSwitch
# 0    -30.00  899.0000        999         0
# 1    -29.99  898.4001        999         0
# 2    -29.98  897.8004        999         0
# 3    -29.97  897.2009        999         0
# 4    -29.96  896.6016        999         0
# ...     ...       ...        ...       ...
# 5996  29.96  896.6016        999         0
# 5997  29.97  897.2009        999         0
# 5998  29.98  897.8004        999         0
# 5999  29.99  898.4001        999         0
# 6000  30.00  899.0000        999         0
#
# [6001 rows x 4 columns]

# %%
df = calc_func(-edges, edges, highest_y, sin_func)

show_function(df)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
highest_y = 20
edges = 10
df = calc_func(-edges, edges, highest_y, func_exp)

show_function(df)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import streamlit as st
x = st.slider('x', )  # 👈 this is a widget
st.write(x, 'squared is', x * x)
# Out:
# 2021-10-19 15:39:09.481
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Users\eilon.eilstein\Anaconda3\lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
